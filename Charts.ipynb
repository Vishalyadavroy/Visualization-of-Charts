# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = sns.load_dataset('titanic')

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['age'], kde=True, bins=30, color='skyblue')
plt.title('Age Distribution of Titanic Passengers', fontsize=14)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='sex', data=df, palette='Set2')
plt.title('Gender Distribution of Titanic Passengers', fontsize=14)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_13668\3372549542.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df, palette='Set2')
